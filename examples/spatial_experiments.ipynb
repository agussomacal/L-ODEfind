# %% [markdown]
# ### L-ODEfind spatial experiments

# %%
import os
import sys
import warnings
notebooks_dir = get_ipython().starting_dir
sys.path.append(os.path.join(notebooks_dir, '..', '.')) 
from src.scripts.spatial.spatial_experiments import *

# %%
warnings.filterwarnings("ignore")
spatial_experiment(
    experiment_name='SpatialExperiments',
    type_of_stress='constant',
    init_cond='trigonometric',
    derivatives2explore={'t': 1, 'x': 1},
    poly2explore=[1, 2],
    regressors2use=[]
)
# Out:
# ...
# String_stress_constant_trigonometric
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ---------------------
# Polynomial degree: 1
# Derivative order: {'t': 0, 'x': 0}Duracion pdefind fitting: 0.6112027168273926
#  {'t': 0, 'x': 1}Duracion pdefind fitting: 0.6230335235595703
#
# ---------------------
# Polynomial degree: 2
# Derivative order: {'t': 0, 'x': 0}Duracion pdefind fitting: 1.1445286273956299
#  {'t': 0, 'x': 1}Duracion pdefind fitting: 1.2360334396362305
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
