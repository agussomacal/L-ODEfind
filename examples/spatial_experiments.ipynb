# %% [markdown]
# ### Imports

# %%
import os
import sys
import warnings
notebooks_dir = get_ipython().starting_dir
sys.path.append(os.path.join(notebooks_dir, '..', '.')) 
from src.scripts.spatial.spatial_experiments import *

# %%
warnings.filterwarnings("ignore")
spatial_experiment(
    experiment_name='SpatialExperiments',
    type_of_stress='constant',
    init_cond='trigonometric',
    derivatives2explore={'t': 1, 'x': 1},
    poly2explore=[1, 2],
    regressors2use=[]
)
# Out:
# ============================
# String_stress_constant_trigonometric
# ---------------------
# Polynomial degree: 1
# Derivative order: {'t': 0, 'x': 0}Duracion pdefind fitting: 0.7015557289123535
#  {'t': 0, 'x': 1}Duracion pdefind fitting: 1.0560896396636963
#
# ---------------------
# Polynomial degree: 2
# Derivative order: {'t': 0, 'x': 0}Duracion pdefind fitting: 1.7463405132293701
#  {'t': 0, 'x': 1}Duracion pdefind fitting: 1.834625482559204
